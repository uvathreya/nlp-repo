# %%
import nltk

# %%
text = "learn php from online platforms"
tokens = nltk.word_tokenize(text)
print(tokens)
# Out:
# ['learn', 'php', 'from', 'online', 'platforms']

# %%
tag = nltk.pos_tag(tokens)
print(tag)
# Out:
# [('learn', 'JJ'), ('php', 'NN'), ('from', 'IN'), ('online', 'NN'), ('platforms', 'NNS')]

# %%
grammar = "NP: {<DT>?<JJ>*<NN>}"
cp  =nltk.RegexpParser(grammar)
result = cp.parse(tag)
print(result)
# Out:
# (S (NP learn/JJ php/NN) from/IN (NP online/NN) platforms/NNS)

# %%
result.draw()    # It will draw the pattern graphically which can be seen in Noun Phrase chunking
